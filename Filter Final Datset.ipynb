# %%
import pandas as pd

df = pd.read_csv("final_integrated_dataset.csv")

# Filter rows where key predictors exist
df_model1 = df[
    df["Avg_Speed"].notna() &
    df["PABT_Passenger_Volume"].notna()
].copy()

print("Original shape:", df.shape)
print("Filtered shape:", df_model1.shape)

df_model1.to_csv("final_integrated_model1.csv", index=False)
# Out:
# Original shape: (325, 16)
# Filtered shape: (192, 16)
